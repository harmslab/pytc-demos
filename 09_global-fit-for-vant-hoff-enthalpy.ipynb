# %% [markdown]
# ## Fit single-site binding curves to experiments at six temperatures to extract the van't Hoff enthalpy.
# Titrations of recombinant human S100A14 with $ZnCl_{2}$ at $5$, $10$, $17$, $25$, $30$ and $35 ^{\circ}C$.  Concentrations were: $[protein] = 110\ \mu M$ and $[ZnCl_{2}]=200\ mM$.  Buffer was $25\ mM$ Trizma, $100\ mM$ NaCl, $pH\ 7.4$.  Buffer was treated with chelex and filtered to $0.22\ \mu m$.  Data collected using a GE ITC200.

# %%
# %matplotlib inline
import pytc

# %%
from pytc import global_connectors

# --------------------------------------------------------------------
# Create a global fitting instance
g1 = pytc.GlobalFit()
vh = pytc.global_connectors.VantHoff("vh")

#--------------------------------------------------------------------------------------------------

t5 = pytc.ITCExperiment("temp-dependence/5C.DH",pytc.indiv_models.SingleSite,shot_start=1)
g1.add_experiment(t5)
g1.link_to_global(t5,"dH",vh.dH)
g1.link_to_global(t5,"K",vh.K)
g1.link_to_global(t5,"fx_competent","g_competent")


#--------------------------------------------------------------------------------------------------

t10 = pytc.ITCExperiment("temp-dependence/10C.DH",pytc.indiv_models.SingleSite,shot_start=1)
g1.add_experiment(t10)
g1.link_to_global(t10,"dH",vh.dH)
g1.link_to_global(t10,"K",vh.K)
g1.link_to_global(t10,"fx_competent","g_competent")

#--------------------------------------------------------------------------------------------------

t17 = pytc.ITCExperiment("temp-dependence/17C.DH",pytc.indiv_models.SingleSite,shot_start=1)
g1.add_experiment(t17)
g1.link_to_global(t17,"dH",vh.dH)
g1.link_to_global(t17,"K",vh.K)
g1.link_to_global(t17,"fx_competent","g_competent")

#--------------------------------------------------------------------------------------------------

t25 = pytc.ITCExperiment("temp-dependence/25C.DH",pytc.indiv_models.SingleSite,shot_start=1)
g1.add_experiment(t25)
g1.link_to_global(t25,"dH",vh.dH)
g1.link_to_global(t25,"K",vh.K)
g1.link_to_global(t25,"fx_competent","g_competent")

#--------------------------------------------------------------------------------------------------

t30 = pytc.ITCExperiment("temp-dependence/30C.DH",pytc.indiv_models.SingleSite,shot_start=1)
g1.add_experiment(t30)
g1.link_to_global(t30,"dH",vh.dH)
g1.link_to_global(t30,"K",vh.K)
g1.link_to_global(t30,"fx_competent","g_competent")

#--------------------------------------------------------------------------------------------------

t35 = pytc.ITCExperiment("temp-dependence/35C.DH",pytc.indiv_models.SingleSite,shot_start=1)
g1.add_experiment(t35)
g1.link_to_global(t35,"dH",vh.dH)
g1.link_to_global(t35,"K",vh.K)
g1.link_to_global(t35,"fx_competent","g_competent")

g1.update_bounds("g_competent",(0.5,1.5))
g1.update_guess("vh_K_ref",1)

# To do ML fit, comment out below and uncomment out the next two lines and uncomment the g.fit() line below
F = pytc.fitters.BayesianFitter(num_steps=1000)
g1.fit(F)
#g1.fit()

# Show the results
fit, ax = g1.plot()
c = g1.corner_plot()
print(g1.fit_as_csv)
# Out:
# # Fit successful? True
# # 2017-05-16 09:09:27.510645
# # Units: cal/mol
# # Fit type: bayesian
# #   bayesian: Burn in: 0.1
# #   bayesian: Final sample number: 90000
# #   bayesian: Initial walker spread: 0.0001
# #   bayesian: Num steps: 1000
# #   bayesian: Num threads: 1
# #   bayesian: Num walkers: 100
# #   bayesian: Use ML guess: True
# # AIC: 1587.2228309506995
# # AICc: 1597.4228309506996
# # BIC: 1624.930172177733
# # F: 1666.3556876443813
# # Rsq: 0.99752412252604
# # Rsq_adjusted: 0.9969251199113722
# # df: 63
# # ln(L): -777.6114154753498
# # num_obs: 78
# # num_param: 15
# type,name,exp_file,value,stdev,bot95,top95,fixed,guess,lower_bound,upper_bound
# global,vh_K_ref,NA,9.06284e+03,2.66839e+02,8.53780e+03,9.64146e+03,False,1.00000e+00,-inf,inf
# global,vh_dH_vanthoff,NA,-6.23127e+03,1.15980e+02,-6.46163e+03,-5.96134e+03,False,0.00000e+00,-inf,inf
# global,g_competent,NA,1.47151e+00,1.16080e-02,1.44643e+00,1.49388e+00,False,1.00000e+00,5.00000e-01,1.50000e+00
# local,dilution_intercept,temp-dependence/5C.DH,-7.44939e+00,5.12498e-01,-8.68887e+00,-6.44205e+00,False,0.00000e+00,-inf,inf
# local,dilution_heat,temp-dependence/5C.DH,1.19591e+04,1.29915e+03,9.36675e+03,1.50796e+04,False,0.00000e+00,-inf,inf
# local,dilution_intercept,temp-dependence/10C.DH,5.61278e+00,4.46983e-01,4.52783e+00,6.49613e+00,False,0.00000e+00,-inf,inf
# local,dilution_heat,temp-dependence/10C.DH,-4.02837e+03,1.07241e+03,-6.16710e+03,-1.41538e+03,False,0.00000e+00,-inf,inf
# local,dilution_intercept,temp-dependence/17C.DH,7.05130e+00,3.61533e-01,6.17817e+00,7.76769e+00,False,0.00000e+00,-inf,inf
# local,dilution_heat,temp-dependence/17C.DH,-1.40175e+03,8.16838e+02,-3.02662e+03,5.51146e+02,False,0.00000e+00,-inf,inf
# local,dilution_intercept,temp-dependence/25C.DH,1.65881e+01,2.82562e-01,1.59296e+01,1.71471e+01,False,0.00000e+00,-inf,inf
# local,dilution_heat,temp-dependence/25C.DH,-2.15038e+04,6.38015e+02,-2.28163e+04,-2.01010e+04,False,0.00000e+00,-inf,inf
# local,dilution_intercept,temp-dependence/30C.DH,1.84942e+01,2.39046e-01,1.79420e+01,1.89649e+01,False,0.00000e+00,-inf,inf
# local,dilution_heat,temp-dependence/30C.DH,-2.10645e+04,5.46404e+02,-2.21602e+04,-1.99031e+04,False,0.00000e+00,-inf,inf
# local,dilution_intercept,temp-dependence/35C.DH,2.19914e+01,1.96476e-01,2.15638e+01,2.23807e+01,False,0.00000e+00,-inf,inf
# local,dilution_heat,temp-dependence/35C.DH,-2.73923e+04,5.06804e+02,-2.83920e+04,-2.63880e+04,False,0.00000e+00,-inf,inf
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
