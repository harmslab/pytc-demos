# %% [markdown]
# # Compare Fitters
# Fits binding of calcium onto EDTA.

# %%
# %matplotlib inline
import pytc

# %%
def fit_with_ml():
    #--------------------------------------------------------------------
    # Create a global fitting instance
    g = pytc.GlobalFit()

    # --------------------------------------------------------------------
    # Load in an experimental data set with a single-site binding model.  Ignore the first two shots
    a = pytc.ITCExperiment("ca-edta/tris-01.DH",pytc.indiv_models.SingleSite,shot_start=2)

    # Add the experiment to the fitter
    g.add_experiment(a)

    # --------------------------------------------------------------------
    # Fit the data
    g.fit()
    
    return g

def fit_with_bootstrap(num_bootstrap=1000):
    # --------------------------------------------------------------------
    # Create a global fitting instance
    g = pytc.GlobalFit()

    # --------------------------------------------------------------------
    # Load in an experimental data set with a single-site binding model.  Ignore the first two shots
    a = pytc.ITCExperiment("ca-edta/tris-01.DH",pytc.indiv_models.SingleSite,shot_start=2)

    # Add the experiment to the fitter
    g.add_experiment(a)

    # --------------------------------------------------------------------
    # Fit the data

    F = pytc.fitters.BootstrapFitter(num_bootstrap=num_bootstrap)
    g.fit(F)

    return g
    
def fit_with_bayes(num_steps=1000):
    # --------------------------------------------------------------------
    # Create a global fitting instance
    g = pytc.GlobalFit()

    # --------------------------------------------------------------------
    # Load in an experimental data set with a single-site binding model.  Ignore the first two shots
    a = pytc.ITCExperiment("ca-edta/tris-01.DH",pytc.indiv_models.SingleSite,shot_start=2)

    # Add the experiment to the fitter
    g.add_experiment(a)

    # --------------------------------------------------------------------
    # Fit the data
    F = pytc.fitters.BayesianFitter(num_steps=num_steps)
    g.fit(F)
    
    return g

# %% [markdown]
# ### Do fits

# %%
print("*** ML fit ***")
ml = fit_with_ml()

print("*** Bootstrap fit ***")
bootstrap = fit_with_bootstrap(num_bootstrap=1000)

print("*** Bayesian fit ***")
bayes = fit_with_bayes(num_steps=1000)
# Out:
# *** ML fit ***
# *** Bootstrap fit ***
# *** Bayesian fit ***

# %% [markdown]
# ### Show fits

# %%
print(ml.fit_as_csv)
fig, ax = ml.plot()
c = ml.corner_plot()
# Out:
# # Fit successful? True
# # 2017-05-15 12:24:22.137916
# # Units: cal/mol
# # Fit type: maximum likelihood
# # AIC: -96.23759423779696
# # AICc: -93.8028116291013
# # BIC: -84.30368995841131
# # F: 292708.2585218862
# # Rsq: 0.9999672039142115
# # Rsq_adjusted: 0.9999637876552752
# # df: 49
# # ln(L): 54.11879711889848
# # num_obs: 54
# # num_param: 5
# type,name,exp_file,value,stdev,bot95,top95,fixed,guess,lower_bound,upper_bound
# local,fx_competent,ca-edta/tris-01.DH,9.73948e-01,8.86443e-05,9.73770e-01,9.74126e-01,False,1.00000e+00,-inf,inf
# local,dH,ca-edta/tris-01.DH,-1.15669e+04,1.00638e+01,-1.15872e+04,-1.15467e+04,False,-4.00000e+03,-inf,inf
# local,dilution_intercept,ca-edta/tris-01.DH,-6.12671e-01,6.71064e-02,-7.47597e-01,-4.77744e-01,False,0.00000e+00,-inf,inf
# local,K,ca-edta/tris-01.DH,4.05476e+07,4.31258e+05,3.96805e+07,4.14147e+07,False,1.00000e+06,-inf,inf
# local,dilution_heat,ca-edta/tris-01.DH,1.15715e+03,4.65377e+02,2.21447e+02,2.09285e+03,False,0.00000e+00,-inf,inf
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
print(bootstrap.fit_as_csv)
fig, ax = bootstrap.plot()
c = bootstrap.corner_plot()
# Out:
# # Fit successful? True
# # 2017-05-15 12:24:23.296479
# # Units: cal/mol
# # Fit type: bootstrap
# #   bootstrap: Num bootstrap: 1000
# #   bootstrap: Perturb size: 1.0
# #   bootstrap: Use experimental error: False
# # AIC: 13.404487499144171
# # AICc: 15.839270107839823
# # BIC: 25.338391778529818
# # F: 292694.5135776877
# # Rsq: 0.9999672022435756
# # Rsq_adjusted: 0.9999637858106147
# # df: 49
# # ln(L): -0.7022437495720858
# # num_obs: 54
# # num_param: 5
# type,name,exp_file,value,stdev,bot95,top95,fixed,guess,lower_bound,upper_bound
# local,fx_competent,ca-edta/tris-01.DH,9.73948e-01,1.28139e-04,9.73703e-01,9.74204e-01,False,1.00000e+00,-inf,inf
# local,dH,ca-edta/tris-01.DH,-1.15675e+04,1.44555e+01,-1.15939e+04,-1.15385e+04,False,-4.00000e+03,-inf,inf
# local,dilution_intercept,ca-edta/tris-01.DH,-6.08354e-01,9.63727e-02,-7.89128e-01,-4.33974e-01,False,0.00000e+00,-inf,inf
# local,K,ca-edta/tris-01.DH,4.05159e+07,6.14403e+05,3.93989e+07,4.17589e+07,False,1.00000e+06,-inf,inf
# local,dilution_heat,ca-edta/tris-01.DH,1.13443e+03,6.74782e+02,-1.27682e+02,2.44950e+03,False,0.00000e+00,-inf,inf
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
print(bayes.fit_as_csv)
fig, ax = bayes.plot()
c = bayes.corner_plot()
# Out:
# # Fit successful? True
# # 2017-05-15 12:24:24.500192
# # Units: cal/mol
# # Fit type: bayesian
# #   bayesian: Burn in: 0.1
# #   bayesian: Final sample number: 90000
# #   bayesian: Initial walker spread: 0.0001
# #   bayesian: Num steps: 1000
# #   bayesian: Num threads: 1
# #   bayesian: Num walkers: 100
# #   bayesian: Use ML guess: True
# # AIC: -96.23309574579686
# # AICc: -93.7983131371012
# # BIC: -84.29919146641122
# # F: 292693.053335658
# # Rsq: 0.9999672028637183
# # Rsq_adjusted: 0.9999637864953557
# # df: 49
# # ln(L): 54.11654787289843
# # num_obs: 54
# # num_param: 5
# type,name,exp_file,value,stdev,bot95,top95,fixed,guess,lower_bound,upper_bound
# local,fx_competent,ca-edta/tris-01.DH,9.73944e-01,1.24882e-04,9.73696e-01,9.74190e-01,False,1.00000e+00,-inf,inf
# local,dH,ca-edta/tris-01.DH,-1.15670e+04,1.42133e+01,-1.15947e+04,-1.15390e+04,False,-4.00000e+03,-inf,inf
# local,dilution_intercept,ca-edta/tris-01.DH,-6.11259e-01,9.48989e-02,-8.00113e-01,-4.25320e-01,False,0.00000e+00,-inf,inf
# local,K,ca-edta/tris-01.DH,4.05679e+07,6.05779e+05,3.93980e+07,4.17785e+07,False,1.00000e+06,-inf,inf
# local,dilution_heat,ca-edta/tris-01.DH,1.14177e+03,6.60013e+02,-1.52595e+02,2.45111e+03,False,0.00000e+00,-inf,inf
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ###  Show timing

# %%
print("*** ML fit ***")
# %timeit fit_with_ml()
print("")

print("*** Bootstrap fit ***")
# %timeit fit_with_bootstrap(1000)
print("")

print("*** Bayesian fit ***")
# %timeit fit_with_bayes(1000)
print("")
# Out:
# *** ML fit ***
# 10 loops, best of 3: 19.1 ms per loop
#
# *** Bootstrap fit ***
# 1 loop, best of 3: 22.6 s per loop
#
# *** Bayesian fit ***
# 1 loop, best of 3: 18.6 s per loop
